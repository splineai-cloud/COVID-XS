# %% [markdown]
# # DPU example: Pneumonia/COVID Covid Model - Pnem4
#
# This notebooks shows an example of DPU applications. The application,
# as well as the DPU IP, is pulled from the official
# [Vitis AI Github Repository](https://github.com/Xilinx/Vitis-AI).
# For more information, please refer to the
# [Xilinx Vitis AI page](https://www.xilinx.com/products/design-tools/vitis/vitis-ai.html).
#
# In this notebook, we will show how to use **Python API** to run DPU tasks.
#
# ## 1. Prepare the overlay
# We will download the overlay onto the board.

# %%
from pynq_dpu import DpuOverlay
overlay = DpuOverlay("../dpu.bit")

# %% [markdown]
# The VAI package has been installed onto your board. There are multiple
# binaries installed; for example, you can check the current DPU status using
# `dexplorer`. You should be able to see reasonable values from the output.

# %%
# !dexplorer -w
# Out:
# [DPU IP Spec]
# IP  Timestamp            : 2020-03-26 13:30:00
# DPU Core Count           : 2
#
# [DPU Core Configuration List]
# DPU Core                 : #0
# DPU Enabled              : Yes
# DPU Arch                 : B4096
# DPU Target Version       : v1.4.1
# DPU Freqency             : 300 MHz
# Ram Usage                : High
# DepthwiseConv            : Enabled
# DepthwiseConv+Relu6      : Enabled
# Conv+Leakyrelu           : Enabled
# Conv+Relu6               : Enabled
# Channel Augmentation     : Enabled
# Average Pool             : Enabled
#
# DPU Core                 : #1
# DPU Enabled              : Yes
# DPU Arch                 : B4096
# DPU Target Version       : v1.4.1
# DPU Freqency             : 300 MHz
# Ram Usage                : High
# DepthwiseConv            : Enabled
# DepthwiseConv+Relu6      : Enabled
# Conv+Leakyrelu           : Enabled
# Conv+Relu6               : Enabled
# Channel Augmentation     : Enabled
# Average Pool             : Enabled

# %%
#!dexplorer -h

# %% [markdown]
# The compiled quantized model may have different kernel names depending on the DPU architectures.
# This piece of information can usually be found when compiling the `*.elf` model file.
#
# The `*.elf` model will be compiled into a shared object file; that file has to be copied to your
# library path for inference in DPU.
#
# By default, the naming convention for model files is:
#
# * Model `*.elf` file: `dpu_<kernel_name>[_0].elf`
# * Shared object `*.so` file: `libdpumodel<kernel_name>.elf`
#
# All of these steps are handled by `load_model()` method.

# %%
overlay.load_model("./models/dpu_Pnem4_0.elf")

# %% [markdown]
# ## 2. Run Python program
#
# We will use Vitis-AI's Python API to run DPU tasks.
# In this example, we will set the number of iterations to 500, meaning
# that a single picture will be taken and classified 500 times.
# Users can adjust this value if they want.

# %%
from ctypes import *
import cv2
import numpy as np
from dnndk import n2cube
import os
import threading
import time
from pynq_dpu import dputils  

lock = threading.Lock()

# %%
#*** Pneumonia and COVID detection Model with 224x224 X-Ray image input

KERNEL_CONV = "Pnem4_0"  
KERNEL_CONV_INPUT = "conv2d_1_convolution"
KERNEL_FC_OUTPUT = "dense_out_MatMul" 

img_dims=224

# %% [markdown]
# The ./data/ folder contains two subfolders with set of X-Ray images 1) sample - with 30 images and 2) images - with 1100 images

# %%
from IPython.display import display
from PIL import Image
 
image_folder = "./data/samples/"    
listimage = [i for i in os.listdir(image_folder)]
print("Sample Image Count={}".format(len(listimage)))  
imfile = listimage[0]
with open("./labels.txt", "r") as f:
    lines = f.readlines()
# Out:
# Sample Image Count=53

# %% [markdown]
# We will also open and initialize the DPU device. We will create a DPU kernel and reuse it.
# Throughout the entire notebook, we don't have to redo this step.
#
# **Note**: if you open and close DPU multiple times, the Jupyter kernel might die;
# this is because the current Vitis-AI implementation requires bitstream to be downloaded by XRT,
# which is not supported by `pynq` package. Hence we encourage users to stay with
# one single DPU session, both for program robustness and higher performance.

# %%
n2cube.dpuOpen()
# Out:
# 0

# %%
kernel = n2cube.dpuLoadKernel(KERNEL_CONV)

# %% [markdown]
# ### Single execution
# We define a function that will use the DPU to make a prediction on an input
# image and provide a softmax output.

# %%
def predict_label(imfile):
    task = n2cube.dpuCreateTask(kernel, 0)

    path = os.path.join(image_folder, imfile)
    img = cv2.imread(path) 
    img = cv2.resize(img, (img_dims, img_dims))
    img = img.astype(np.float32)
    img = (img/255.0) 
        
    """Get input Tensor"""
    tensor = n2cube.dpuGetInputTensor(task, KERNEL_CONV_INPUT)
    input_len = n2cube.dpuGetInputTensorSize(task, KERNEL_CONV_INPUT)   
    #print(input_len)
        
    """Set input Tensor"""
    n2cube.dpuSetInputTensorInHWCFP32(task, KERNEL_CONV_INPUT, img, input_len)

    """Model run on DPU"""
    n2cube.dpuRunTask(task)
        
    """Get the output Tensor size from FC output"""
    size = n2cube.dpuGetOutputTensorSize(task, KERNEL_FC_OUTPUT)

    """Get the output Tensor channel from FC output"""
    channel = n2cube.dpuGetOutputTensorChannel(task, KERNEL_FC_OUTPUT)

    softmax = np.zeros(size,dtype=np.float32)

    """Get FC result"""
    conf = n2cube.dpuGetOutputTensorAddress(task, KERNEL_FC_OUTPUT)

    """Get output scale of FC"""
    outputScale = n2cube.dpuGetOutputTensorScale(task, KERNEL_FC_OUTPUT)

    """Run softmax"""
    softmax = n2cube.dpuRunSoftmax(conf, channel, size // channel, outputScale)
     
    #print("size=", size)
    #print("channel=", channel)
    #print("outputScale=", outputScale)
    print("softmax =", softmax)

    n2cube.dpuDestroyTask(task)
    
    return lines[np.argmax(softmax)]

# %%
print("INFO: test with sample X-Ray images")
i = 0
for img in listimage:
    print("{}  {}".format(i, img))
    i = i + 1 
    label = predict_label(img)
    print('Class label: {}'.format(label))
# Out:
# INFO: test with sample X-Ray images
# 0  COVID_1-s2.0-S1684118220300608-main.pdf-002.jpg
# softmax = [ 0.02443578  0.05861839  0.91694582]
# Class label: COVID
#
# 1  COVID_covid-19-pneumonia-53.jpg
# softmax = [ 0.95312124  0.04187723  0.00500152]
# Class label: NORMAL
#
# 2  PNEUMONIA_fe1289af-87c8-49c6-800c-1e87b2296df8.jpg
# softmax = [ 0.0210632   0.89563018  0.08330659]
# Class label: PNEUMONIA
#
# 3  NORMAL_8d3d0ba6-799d-4874-a804-75a4c0cf4ae6.jpg
# softmax = [ 0.40176335  0.24368179  0.35455489]
# Class label: NORMAL
#
# 4  COVID_covid-19-pneumonia-8.jpg
# softmax = [  1.39476397e-04   2.47227820e-03   9.97388244e-01]
# Class label: COVID
#
# 5  PNEUMONIA_849217ad-5cb2-4a87-9796-420b69722b14.jpg
# softmax = [ 0.02925739  0.75455809  0.21618453]
# Class label: PNEUMONIA
#
# 6  COVID_COVID-00027.jpg
# softmax = [ 0.0011683   0.00103103  0.99780071]
# Class label: COVID
#
# 7  NORMAL_8cfcc69b-d659-4888-8551-790891d8568e.jpg
# softmax = [  9.39911306e-01   6.00865223e-02   2.12450914e-06]
# Class label: NORMAL
#
# 8  COVID_COVID-00038.jpg
# softmax = [ 0.52825212  0.3204011   0.15134676]
# Class label: NORMAL
#
# 9  COVID_COVID-00006.jpg
# softmax = [  1.58376031e-04   3.79924342e-04   9.99461710e-01]
# Class label: COVID
#
# 10  PNEUMONIA_852156be-0aab-4dc7-95d6-eda950096d0f.jpg
# softmax = [ 0.28996751  0.69559586  0.01443663]
# Class label: PNEUMONIA
#
# 11  PNEUMONIA_84032d11-9143-45a2-b3e9-955f9dc4b497.jpg
# softmax = [  2.18244782e-03   9.97694433e-01   1.23125268e-04]
# Class label: PNEUMONIA
#
# 12  NORMAL_fc4cd37e-7bae-425d-9465-bfdd0ecf0b63.jpg
# softmax = [  9.84093547e-01   1.59063917e-02   9.09051501e-09]
# Class label: NORMAL
#
# 13  PNEUMONIA_fef7b294-017c-4491-9e57-119086855785.jpg
# softmax = [  9.60985781e-05   9.99863923e-01   4.00598437e-05]
# Class label: PNEUMONIA
#
# 14  PNEUMONIA_85727853-cb45-478d-a517-a0f0c85d0eb5.jpg
# softmax = [  2.18257261e-03   9.97751534e-01   6.59079815e-05]
# Class label: PNEUMONIA
#
# 15  NORMAL_8c62b364-84be-4c83-9c3a-43df335a1978.jpg
# softmax = [ 0.34841064  0.65091676  0.00067259]
# Class label: PNEUMONIA
#
# 16  COVID_extubation-4.jpg
# softmax = [ 0.00243339  0.01586769  0.98169887]
# Class label: COVID
#
# 17  NORMAL_fc6599d7-fa85-4361-b26e-e51f2375ecf2.jpg
# softmax = [  9.84086871e-01   1.59062836e-02   6.85151281e-06]
# Class label: NORMAL
#
# 18  NORMAL_8d091d33-6dfc-431e-b459-995016771709.jpg
# softmax = [  9.62671518e-01   3.73268276e-02   1.69463522e-06]
# Class label: NORMAL
#
# 19  COVID_gr1_lrg-b.jpg
# softmax = [  2.30429432e-04   3.35272838e-04   9.99434292e-01]
# Class label: COVID
#
# 20  COVID_covid-19-pneumonia-19.jpg
# softmax = [ 0.25851509  0.48296979  0.25851509]
# Class label: PNEUMONIA
#
# 21  PNEUMONIA_fdfce1ff-203e-4b23-a360-3803558a7f7a.jpg
# softmax = [ 0.00240859  0.9716965   0.02589484]
# Class label: PNEUMONIA
#
# 22  COVID_16654_2_1.jpg
# softmax = [ 0.03668014  0.94599342  0.01732647]
# Class label: PNEUMONIA
#
# 23  NORMAL_fe8460ea-9f61-4f29-b315-ffb5c01f4eef.jpg
# softmax = [  9.85935628e-01   1.40636163e-02   8.19833758e-07]
# Class label: NORMAL
#
# 24  PNEUMONIA_fe2e6108-895f-4469-8712-7965544dd47c.jpg
# softmax = [ 0.0108341   0.97525465  0.01391126]
# Class label: PNEUMONIA
#
# 25  COVID_AR-1.jpg
# softmax = [ 0.0066198   0.01091421  0.98246598]
# Class label: COVID
#
# 26  NORMAL_8c82ad94-205c-435a-a510-e4be16cf5657.jpg
# softmax = [ 0.73050678  0.26873842  0.00075483]
# Class label: NORMAL
#
# 27  PNEUMONIA_863a923a-3906-42d3-92db-76c900091fce.jpg
# softmax = [ 0.01127223  0.61544281  0.37328494]
# Class label: PNEUMONIA
#
# 28  PNEUMONIA_844ac956-e1e2-4f27-b58c-390d6405c3a0.jpg
# softmax = [  8.04039126e-04   9.99137700e-01   5.82444009e-05]
# Class label: PNEUMONIA
#
# 29  NORMAL_fca8b18a-9851-4115-af53-6d7540820888.jpg
# softmax = [  9.84079361e-01   1.59061607e-02   1.45045415e-05]
# Class label: NORMAL
#
# 30  NORMAL_8c4421ee-115a-472c-b3cd-48c6c3b8e42b.jpg
# softmax = [ 0.74002725  0.24025166  0.01972106]
# Class label: NORMAL
#
# 31  NORMAL_fe02ac25-6a2a-4c6b-909e-c8a9c7c67f53.jpg
# softmax = [  9.87568319e-01   1.24316504e-02   1.79634885e-09]
# Class label: NORMAL
#
# 32  PNEUMONIA_86e9848d-dd57-48b4-b016-5b1447fdbd58.jpg
# softmax = [  8.47958217e-05   9.99735713e-01   1.79512746e-04]
# Class label: PNEUMONIA
#
# 33  COVID_88de9d8c39e946abd495b37cd07d89e5-2ee6-0.jpg
# softmax = [ 0.05472905  0.58839273  0.35687822]
# Class label: PNEUMONIA
#
# 34  COVID_covid-19-pneumonia-58-day-3.jpg
# softmax = [  2.95812788e-04   4.87712852e-04   9.99216497e-01]
# Class label: COVID
#
# 35  COVID_COVID-00001.jpg
# softmax = [ 0.00216621  0.00756083  0.99027294]
# Class label: COVID
#
# 36  NORMAL_fc35980f-918e-4f10-b3e4-d4202394e7da.jpg
# softmax = [  9.79667425e-01   2.03323476e-02   2.05968590e-07]
# Class label: NORMAL
#
# 37  COVID_COVID-00016.jpg
# softmax = [  8.47508563e-05   7.09610293e-04   9.99205649e-01]
# Class label: COVID
#
# 38  NORMAL_8d768b9e-92cb-4343-9a2a-20ce3d137695.jpg
# softmax = [ 0.74174607  0.24080969  0.0174442 ]
# Class label: NORMAL
#
# 39  COVID_COVID-00033.jpg
# softmax = [ 0.00460073  0.1186545   0.87674475]
# Class label: COVID
#
# 40  NORMAL_fcbe3898-4d24-402a-a64a-f11c95d23235.jpg
# softmax = [  9.79667664e-01   2.03323532e-02   1.69069381e-08]
# Class label: NORMAL
#
# 41  COVID_COVID-00037.jpg
# softmax = [ 0.00452918  0.13236202  0.86310875]
# Class label: COVID
#
# 42  PNEUMONIA_02c34d5b-16e9-412e-a385-ccd8cbceae16.jpg
# softmax = [  3.72663931e-06   9.99996305e-01   2.84532433e-08]
# Class label: PNEUMONIA
#
# 43  COVID_extubation-13.jpg
# softmax = [ 0.00310838  0.02026915  0.97662246]
# Class label: COVID
#
# 44  PNEUMONIA_8489c930-19a8-4895-9211-4efd3d38ae58.jpg
# softmax = [ 0.7948575   0.20097144  0.00417103]
# Class label: NORMAL
#
# 45  COVID_covid-19-pneumonia-20-pa-on-admission.jpg
# softmax = [ 0.11571535  0.02925742  0.8550272 ]
# Class label: COVID
#
# 46  PNEUMONIA_fcf5cd90-1a5d-4e45-925e-ff82dcbdc0ad.jpg
# softmax = [  2.03425749e-04   9.99790490e-01   6.14292503e-06]
# Class label: PNEUMONIA
#
# 47  PNEUMONIA_fcd6452c-680d-40a6-9fc6-1793eb3ca0a8.jpg
# softmax = [  1.14787454e-05   9.99986529e-01   1.99470674e-06]
# Class label: PNEUMONIA
#
# 48  COVID_16708_5_1.jpg
# softmax = [ 0.07109852  0.06274422  0.86615723]
# Class label: COVID
#
# 49  COVID_COVID-00036.jpg
# softmax = [ 0.09269618  0.68493724  0.22236659]
# Class label: PNEUMONIA
#
# 50  NORMAL_8c2b6caa-41cd-45c0-95f0-de71c3e9186b.jpg
# softmax = [ 0.67658663  0.21965551  0.10375792]
# Class label: NORMAL
#
# 51  COVID_16660_2_1.jpg
# softmax = [ 0.00905864  0.92400658  0.06693481]
# Class label: PNEUMONIA
#
# 52  COVID_kjr-21-e24-g002-l-a.jpg
# softmax = [ 0.04309024  0.19311704  0.76379269]
# Class label: COVID

# %% [markdown]
# ### Multiple executions
# After we have verified the correctness of a single execution, we can
# try multiple executions and measure the throughput in Frames Per Second (FPS).
#
# Let's define a function that processes a single image in multiple iterations.
# The parameters are:
# * `kernel`: DPU kernel.
# * `img`: image to be classified.
# * `count` : test rounds count.
#
# The number of iterations is defined as `num_iterations` in previous cells.

# %%
path = os.path.join(image_folder, imfile)
img = cv2.imread(path) 
img = cv2.resize(img, (img_dims, img_dims))
img = img.astype(np.float32)
img = (img/255.0) 

def run_dpu_task(kernel, img, count):
    task = n2cube.dpuCreateTask(kernel, 0)
    
    count = 0
    while count < num_iterations:
           
        """Get input Tensor"""
        tensor = n2cube.dpuGetInputTensor(task, KERNEL_CONV_INPUT)
        input_len = n2cube.dpuGetInputTensorSize(task, KERNEL_CONV_INPUT)   
        
        """Set input Tensor"""
        n2cube.dpuSetInputTensorInHWCFP32(task, KERNEL_CONV_INPUT, img, input_len)

        """Model run on DPU"""
        n2cube.dpuRunTask(task)
        
        """Get the output Tensor size from FC output"""
        size = n2cube.dpuGetOutputTensorSize(task, KERNEL_FC_OUTPUT)

        """Get the output Tensor channel from FC output"""
        channel = n2cube.dpuGetOutputTensorChannel(task, KERNEL_FC_OUTPUT)

        softmax = np.zeros(size,dtype=np.float32)

        """Get FC result"""
        conf = n2cube.dpuGetOutputTensorAddress(task, KERNEL_FC_OUTPUT)

        """Get output scale of FC"""
        outputScale = n2cube.dpuGetOutputTensorScale(task, KERNEL_FC_OUTPUT)

        """Run softmax"""
        softmax = n2cube.dpuRunSoftmax(conf, channel, size // channel, outputScale)

        lock.acquire()
        count = count + threadnum
        lock.release()

    n2cube.dpuDestroyTask(task)

# %% [markdown]
# Now we are able to run the batch processing and print out DPU throughput.
# Users can change the image folder to point to other picture locations.
# We will use the previously defined and classified image `img` and process it for
# `num_interations` times.
#
# In this example, we will just use a single thread.
#
# The following cell may take a while to run. Please be patient.

# %%
threadAll = []
threadnum = 1
num_iterations = 500
start = time.time()

for i in range(threadnum):
    t1 = threading.Thread(target=run_dpu_task, args=(kernel, img, i))
    threadAll.append(t1)
for x in threadAll:
    x.start()
for x in threadAll:
    x.join()

end = time.time()

fps = float(num_iterations/(end-start))
print("%.2f FPS" % fps)
# Out:
# 59.99 FPS

# %%
threadAll = []
threadnum = 4
num_iterations = 500
start = time.time()

for i in range(threadnum):
    t1 = threading.Thread(target=run_dpu_task, args=(kernel, img, i))
    threadAll.append(t1)
for x in threadAll:
    x.start()
for x in threadAll:
    x.join()

end = time.time()

fps = float(num_iterations/(end-start))
print("%.2f FPS" % fps)
# Out:
# 120.15 FPS

# %%
threadAll = []
threadnum = 8
num_iterations = 500
start = time.time()

for i in range(threadnum):
    t1 = threading.Thread(target=run_dpu_task, args=(kernel, img, i))
    threadAll.append(t1)
for x in threadAll:
    x.start()
for x in threadAll:
    x.join()

end = time.time()

fps = float(num_iterations/(end-start))
print("%.2f FPS" % fps)
# Out:
# 116.56 FPS

# %% [markdown]
# #### Following function does the testing with 1100 images
# 500 - NORMAL, 500 - PNEUMONIA and 100 - COVID  X-Ray images

# %%
def run_tasks(kernel):
    task = n2cube.dpuCreateTask(kernel, 0)
    
    o_count = [0, 0, 0]
    p_count = [0, 0, 0]
     
    image_folder = "./data/images/"  
    listimage = [i for i in os.listdir(image_folder)] 
    num_iterations=len(listimage)
    print("Total Test Image Count={}".format(num_iterations)) 
    count = 0

    with open("./labels.txt", "r") as f:
        lines = f.readlines()
        
    print("====================== Start: Test results with 100 COVID mark X-Rays ==================")
    while count < num_iterations:
        imfile = listimage[count]
        path = os.path.join(image_folder, imfile)
        img = cv2.imread(path) 
        img = cv2.resize(img, (img_dims, img_dims))
        img = img.astype(np.float32)
        img = (img/255.0) 
        
        """Get input Tensor"""
        tensor = n2cube.dpuGetInputTensor(task, KERNEL_CONV_INPUT)
        input_len = n2cube.dpuGetInputTensorSize(task, KERNEL_CONV_INPUT)   
        #print(input_len)
        
        """Set input Tensor"""
        n2cube.dpuSetInputTensorInHWCFP32(task, KERNEL_CONV_INPUT, img, input_len)

        """Model run on DPU"""
        n2cube.dpuRunTask(task)
        
        """Get the output Tensor size from FC output"""
        size = n2cube.dpuGetOutputTensorSize(task, KERNEL_FC_OUTPUT)

        """Get the output Tensor channel from FC output"""
        channel = n2cube.dpuGetOutputTensorChannel(task, KERNEL_FC_OUTPUT)

        softmax = np.zeros(size,dtype=np.float32)

        """Get FC result"""
        conf = n2cube.dpuGetOutputTensorAddress(task, KERNEL_FC_OUTPUT)

        """Get output scale of FC"""
        outputScale = n2cube.dpuGetOutputTensorScale(task, KERNEL_FC_OUTPUT)

        """Run softmax"""
        softmax = n2cube.dpuRunSoftmax(conf, channel, size // channel, outputScale)

        expected = False
        if imfile[0] == 'N':  
            o_count[0] = o_count[0] + 1 
        elif imfile[0] == 'P':
            o_count[1] = o_count[1] + 1 
        elif imfile[0] == 'C':
            o_count[2] = o_count[2] + 1 
        else:
            print("ERROR: Invalid file tag in {}".format(imfile))
        
        label = np.argmax(softmax)
        p_count[label] = p_count[label] + 1 
        slabel = lines[label] 
        if imfile[0] == 'C':
            print("Name= {}  Softmax={}  Prediction= {}".format(imfile, softmax, slabel))
        count = count + 1
    print("====================== Done: Test results with COVID mark X-Rays ==================")
    print("\n")
    print("====================== Start: Test results with All X-Rays ==================")
    print("Actual #(NORMAL, PNEUMONIA, COVID)= ({}, {}, {})". format(o_count[0], o_count[1], o_count[2]))
    print("Predic #(NORMAL, PNEUMONIA, COVID)= ({}, {}, {})". format(p_count[0], p_count[1], p_count[2]))
    print("Percentage Prediction (NORMAL, PNEUMONIA, COVID)=({}, {}, {})".format((p_count[0]*100)/o_count[0], (p_count[1]*100)/o_count[1],
                                                                                 (p_count[2]*100)/o_count[2])) 
    n2cube.dpuDestroyTask(task)

# %%
run_tasks(kernel)
# Out:
# Total Test Image Count=1100
# ====================== Start: Test results with 100 COVID mark X-Rays ==================
# Name= COVID_COVID-19(153).png  Softmax=[ 0.0175802   0.02257342  0.95984638]  Prediction= COVID
#
# Name= COVID_1-s2.0-S1684118220300608-main.pdf-002.jpg  Softmax=[ 0.02443578  0.05861839  0.91694582]  Prediction= COVID
#
# Name= COVID_covid-19-pneumonia-53.jpg  Softmax=[ 0.95312124  0.04187723  0.00500152]  Prediction= NORMAL
#
# Name= COVID_COVID-19 (128).png  Softmax=[ 0.05191923  0.02779036  0.92029041]  Prediction= COVID
#
# Name= COVID_COVID-19 (55).png  Softmax=[ 0.009626    0.00849492  0.98187906]  Prediction= COVID
#
# Name= COVID_covid-19-pneumonia-8.jpg  Softmax=[  1.39476397e-04   2.47227820e-03   9.97388244e-01]  Prediction= COVID
#
# Name= COVID_covid-19-pneumonia-14-PA.png  Softmax=[  2.30321413e-04   8.03900766e-04   9.98965800e-01]  Prediction= COVID
#
# Name= COVID_F63AB6CE-1968-4154-A70F-913AF154F53D.jpeg  Softmax=[ 0.02843879  0.23811507  0.73344612]  Prediction= COVID
#
# Name= COVID_COVID-19 (131).png  Softmax=[ 0.02403561  0.07403488  0.9019295 ]  Prediction= COVID
#
# Name= COVID_COVID-19 (14).png  Softmax=[ 0.00548118  0.43542373  0.55909514]  Prediction= COVID
#
# Name= COVID_1-s2.0-S1684118220300682-main.pdf-003-b1.png  Softmax=[ 0.08330659  0.0210632   0.89563018]  Prediction= COVID
#
# Name= COVID_COVID-19(193).png  Softmax=[  5.51949313e-04   1.50035368e-03   9.97947693e-01]  Prediction= COVID
#
# Name= COVID_COVID-19 (2).png  Softmax=[ 0.00149643  0.00316794  0.9953357 ]  Prediction= COVID
#
# Name= COVID_COVID-00027.jpg  Softmax=[ 0.0011683   0.00103103  0.99780071]  Prediction= COVID
#
# Name= COVID_COVID-19 (57).png  Softmax=[  2.95771810e-04   6.26148889e-04   9.99078035e-01]  Prediction= COVID
#
# Name= COVID_CR.1.2.840.113564.1722810170.20200320183426328780.1003000225002.png  Softmax=[  3.17244604e-03   9.96752918e-01   7.46087753e-05]  Prediction= PNEUMONIA
#
# Name= COVID_COVID-19(195).png  Softmax=[ 0.00712519  0.05965852  0.93321633]  Prediction= COVID
#
# Name= COVID_COVID-19(164).png  Softmax=[ 0.02228836  0.23962246  0.7380892 ]  Prediction= COVID
#
# Name= COVID_1.CXRCTThoraximagesofCOVID-19fromSingapore.pdf-002-fig3b.png  Softmax=[  4.87211044e-04   1.32437702e-03   9.98188436e-01]  Prediction= COVID
#
# Name= COVID_COVID-19 (4).png  Softmax=[ 0.00340281  0.16395664  0.83264059]  Prediction= COVID
#
# Name= COVID_COVID-19 (81).png  Softmax=[ 0.00283515  0.10638811  0.89077675]  Prediction= COVID
#
# Name= COVID_COVID-19(208).png  Softmax=[ 0.00162019  0.04734903  0.95103073]  Prediction= COVID
#
# Name= COVID_COVID-19(188).png  Softmax=[ 0.04966976  0.17336449  0.77696574]  Prediction= COVID
#
# Name= COVID_6b44464d-73a7-4cf3-bbb6-ffe7168300e3.annot.original.jpeg  Softmax=[ 0.01558802  0.02001541  0.96439654]  Prediction= COVID
#
# Name= COVID_ciaa199.pdf-001-c.png  Softmax=[  9.09064431e-04   2.18073209e-03   9.96910214e-01]  Prediction= COVID
#
# Name= COVID_CR.1.2.840.113564.1722810170.20200321002029359840.1003000225002.png  Softmax=[ 0.18641962  0.23936753  0.57421285]  Prediction= COVID
#
# Name= COVID_85E52EB3-56E9-4D67-82DA-DEA247C82886.jpeg  Softmax=[ 0.00256318  0.08488093  0.91255593]  Prediction= COVID
#
# Name= COVID_COVID-19 (94).png  Softmax=[ 0.00142113  0.05332744  0.94525146]  Prediction= COVID
#
# Name= COVID_COVID-00038.jpg  Softmax=[ 0.52825212  0.3204011   0.15134676]  Prediction= NORMAL
#
# Name= COVID_COVID-00006.jpg  Softmax=[  1.58376031e-04   3.79924342e-04   9.99461710e-01]  Prediction= COVID
#
# Name= COVID_COVID-19 (24).png  Softmax=[  2.61077919e-04   4.30444692e-04   9.99308467e-01]  Prediction= COVID
#
# Name= COVID_COVID-19 (6).png  Softmax=[  5.52046637e-04   1.32429099e-03   9.98123646e-01]  Prediction= COVID
#
# Name= COVID_COVID-19 (65).png  Softmax=[ 0.84211648  0.08875842  0.06912513]  Prediction= NORMAL
#
# Name= COVID_CR.1.2.840.113564.1722810170.20200402113955515630.1003000225002.png  Softmax=[ 0.02271238  0.66375291  0.31353468]  Prediction= PNEUMONIA
#
# Name= COVID_COVID-19 (71).png  Softmax=[ 0.00103103  0.0011683   0.99780071]  Prediction= COVID
#
# Name= COVID_covid-19-pneumonia-67.jpeg  Softmax=[ 0.00169186  0.00521129  0.99309683]  Prediction= COVID
#
# Name= COVID_COVID-19(174).png  Softmax=[ 0.0216266   0.05878718  0.91958624]  Prediction= COVID
#
# Name= COVID_COVID-19 (44).png  Softmax=[ 0.00520879  0.00217135  0.99261987]  Prediction= COVID
#
# Name= COVID_extubation-4.jpg  Softmax=[ 0.00243339  0.01586769  0.98169887]  Prediction= COVID
#
# Name= COVID_COVID-19 (108).png  Softmax=[ 0.00132175  0.00246935  0.99620885]  Prediction= COVID
#
# Name= COVID_COVID-19 (1).png  Softmax=[  4.30319196e-04   5.52540761e-04   9.99017179e-01]  Prediction= COVID
#
# Name= COVID_COVID-19(187).png  Softmax=[  4.73938100e-02   9.51930106e-01   6.76036463e-04]  Prediction= PNEUMONIA
#
# Name= COVID_gr1_lrg-b.jpg  Softmax=[  2.30429432e-04   3.35272838e-04   9.99434292e-01]  Prediction= COVID
#
# Name= COVID_COVID-19 (117).png  Softmax=[ 0.00192385  0.00149829  0.9965778 ]  Prediction= COVID
#
# Name= COVID_CD50BA96-6982-4C80-AE7B-5F67ACDBFA56.jpeg  Softmax=[ 0.01558802  0.02001541  0.96439654]  Prediction= COVID
#
# Name= COVID_covid-19-pneumonia-19.jpg  Softmax=[ 0.25851509  0.48296979  0.25851509]  Prediction= PNEUMONIA
#
# Name= COVID_16654_2_1.jpg  Softmax=[ 0.03668014  0.94599342  0.01732647]  Prediction= PNEUMONIA
#
# Name= COVID_03BF7561-A9BA-4C3C-B8A0-D3E585F73F3C.jpeg  Softmax=[ 0.00314872  0.00755338  0.98929793]  Prediction= COVID
#
# Name= COVID_AR-1.jpg  Softmax=[ 0.0066198   0.01091421  0.98246598]  Prediction= COVID
#
# Name= COVID_1B734A89-A1BF-49A8-A1D3-66FAFA4FAC5D.jpeg  Softmax=[ 0.01766842  0.01766842  0.96466315]  Prediction= COVID
#
# Name= COVID_COVID-19(216).png  Softmax=[ 0.2312239   0.14024439  0.62853169]  Prediction= COVID
#
# Name= COVID_COVID-19 (10).png  Softmax=[ 0.05269186  0.01332259  0.93398559]  Prediction= COVID
#
# Name= COVID_COVID-19 (72).png  Softmax=[ 0.74302262  0.06911187  0.18786554]  Prediction= NORMAL
#
# Name= COVID_CR.1.2.840.113564.1722810170.20200320103403375580.1003000225002.png  Softmax=[ 0.01758231  0.58224612  0.40017152]  Prediction= PNEUMONIA
#
# Name= COVID_16669_3_1.jpeg  Softmax=[  2.29568745e-04   9.95701194e-01   4.06920351e-03]  Prediction= PNEUMONIA
#
# Name= COVID_2966893D-5DDF-4B68-9E2B-4979D5956C8E.jpeg  Softmax=[ 0.00184579  0.04201004  0.95614415]  Prediction= COVID
#
# Name= COVID_88de9d8c39e946abd495b37cd07d89e5-2ee6-0.jpg  Softmax=[ 0.05472905  0.58839273  0.35687822]  Prediction= PNEUMONIA
#
# Name= COVID_COVID-19 (109).png  Softmax=[ 0.00356647  0.00755022  0.98888332]  Prediction= COVID
#
# Name= COVID_covid-19-pneumonia-58-day-3.jpg  Softmax=[  2.95812788e-04   4.87712852e-04   9.99216497e-01]  Prediction= COVID
#
# Name= COVID_COVID-00001.jpg  Softmax=[ 0.00216621  0.00756083  0.99027294]  Prediction= COVID
#
# Name= COVID_fff49165-b22d-4bb4-b9d1-d5d62c52436c.annot.original.png  Softmax=[ 0.50614655  0.09966616  0.3941873 ]  Prediction= NORMAL
#
# Name= COVID_COVID-19 (29).png  Softmax=[ 0.00649794  0.02912176  0.96438026]  Prediction= COVID
#
# Name= COVID_COVID-19 (76).png  Softmax=[  1.79508410e-04   1.08877364e-04   9.99711573e-01]  Prediction= COVID
#
# Name= COVID_COVID-00016.jpg  Softmax=[  8.47508563e-05   7.09610293e-04   9.99205649e-01]  Prediction= COVID
#
# Name= COVID_COVID-00033.jpg  Softmax=[ 0.00460073  0.1186545   0.87674475]  Prediction= COVID
#
# Name= COVID_COVID-19(148).png  Softmax=[ 0.04104008  0.02489207  0.9340679 ]  Prediction= COVID
#
# Name= COVID_COVID-19(210).png  Softmax=[ 0.03284374  0.45339382  0.51376247]  Prediction= COVID
#
# Name= COVID_COVID-19 (22).png  Softmax=[  4.87211044e-04   1.32437702e-03   9.98188436e-01]  Prediction= COVID
#
# Name= COVID_COVID-19 (133).png  Softmax=[ 0.00942658  0.02903591  0.96153748]  Prediction= COVID
#
# Name= COVID_8FDE8DBA-CFBD-4B4C-B1A4-6F36A93B7E87.jpeg  Softmax=[ 0.87620807  0.11858186  0.00521012]  Prediction= NORMAL
#
# Name= COVID_CR.1.2.840.113564.1722810170.20200320071047906500.1003000225002.png  Softmax=[ 0.00116341  0.00521405  0.99362254]  Prediction= COVID
#
# Name= COVID_COVID-00037.jpg  Softmax=[ 0.00452918  0.13236202  0.86310875]  Prediction= COVID
#
# Name= COVID_nejmoa2001191_f3-PA.jpeg  Softmax=[ 0.01391126  0.0108341   0.97525465]  Prediction= COVID
#
# Name= COVID_extubation-13.jpg  Softmax=[ 0.00310838  0.02026915  0.97662246]  Prediction= COVID
#
# Name= COVID_covid-19-pneumonia-20-pa-on-admission.jpg  Softmax=[ 0.11571535  0.02925742  0.8550272 ]  Prediction= COVID
#
# Name= COVID_COVID-19 (15).png  Softmax=[ 0.01863433  0.08351327  0.89785236]  Prediction= COVID
#
# Name= COVID_COVID-19(165).png  Softmax=[ 0.02228836  0.23962246  0.7380892 ]  Prediction= COVID
#
# Name= COVID_COVID-19(170).png  Softmax=[ 0.68493724  0.22236657  0.09269618]  Prediction= NORMAL
#
# Name= COVID_COVID-19 (66).png  Softmax=[  7.05595791e-01   2.94136077e-01   2.68217380e-04]  Prediction= NORMAL
#
# Name= COVID_31BA3780-2323-493F-8AED-62081B9C383B.jpeg  Softmax=[ 0.00310039  0.59082907  0.40607047]  Prediction= PNEUMONIA
#
# Name= COVID_COVID-19(209).png  Softmax=[ 0.03284374  0.45339382  0.51376247]  Prediction= COVID
#
# Name= COVID_6CB4EFC6-68FA-4CD5-940C-BEFA8DAFE9A7.jpeg  Softmax=[ 0.0099609   0.37378004  0.6162591 ]  Prediction= COVID
#
# Name= COVID_COVID-19 (52).png  Softmax=[ 0.04116047  0.02203161  0.93680787]  Prediction= COVID
#
# Name= COVID_16708_5_1.jpg  Softmax=[ 0.07109852  0.06274422  0.86615723]  Prediction= COVID
#
# Name= COVID_COVID-00036.jpg  Softmax=[ 0.09269618  0.68493724  0.22236659]  Prediction= PNEUMONIA
#
# Name= COVID_COVID-19 (73).png  Softmax=[  9.10548086e-04   5.52275334e-04   9.98537183e-01]  Prediction= COVID
#
# Name= COVID_covid-19-pneumonia-28.png  Softmax=[ 0.27860069  0.58979768  0.13160165]  Prediction= PNEUMONIA
#
# Name= COVID_ciaa199.pdf-001-b.png  Softmax=[ 0.00132366  0.00103086  0.99764544]  Prediction= COVID
#
# Name= COVID_COVID-19 (31).png  Softmax=[  3.79414327e-04   1.50061282e-03   9.98120010e-01]  Prediction= COVID
#
# Name= COVID_16660_2_1.jpg  Softmax=[ 0.00905864  0.92400658  0.06693481]  Prediction= PNEUMONIA
#
# Name= COVID_kjr-21-e24-g002-l-a.jpg  Softmax=[ 0.04309024  0.19311704  0.76379269]  Prediction= COVID
#
# Name= COVID_COVID-19 (59).png  Softmax=[ 0.00279618  0.00169597  0.99550784]  Prediction= COVID
#
# Name= COVID_COVID-19(203).png  Softmax=[ 0.00812314  0.05296953  0.93890733]  Prediction= COVID
#
# Name= COVID_COVID-19 (45).png  Softmax=[ 0.00270851  0.03299637  0.96429515]  Prediction= COVID
#
# Name= COVID_COVID-19 (51).png  Softmax=[ 0.09310488  0.0235406   0.88335454]  Prediction= COVID
#
# Name= COVID_COVID-19 (12).png  Softmax=[ 0.02252071  0.01987445  0.95760489]  Prediction= COVID
#
# Name= COVID_COVID-19 (91).png  Softmax=[ 0.07353289  0.03065307  0.89581406]  Prediction= COVID
#
# Name= COVID_ryct.2020200034.fig5-day0.jpeg  Softmax=[  7.30919003e-01   2.68890053e-01   1.90958846e-04]  Prediction= NORMAL
#
# Name= COVID_CR.1.2.840.113564.1722810170.20200329171322703880.1003000225002.png  Softmax=[  3.17013962e-03   9.96028304e-01   8.01536837e-04]  Prediction= PNEUMONIA
#
# Name= COVID_COVID-19(218).png  Softmax=[ 0.00812314  0.05296953  0.93890733]  Prediction= COVID
#
# ====================== Done: Test results with COVID mark X-Rays ==================
#
#
# ====================== Start: Test results with All X-Rays ==================
# Actual #(NORMAL, PNEUMONIA, COVID)= (500, 500, 100)
# Predic #(NORMAL, PNEUMONIA, COVID)= (549, 459, 92)
# Percentage Prediction (NORMAL, PNEUMONIA, COVID)=(109.8, 91.8, 92.0)

# %% [markdown]
# ### Clean up
#
# Finally, when you are done with the DPU experiments, remember to destroy the kernel and close the DPU.

# %%
n2cube.dpuDestroyKernel(kernel)
n2cube.dpuClose()
# Out:
# 0

# %% [markdown]
# Copyright (C) 2020 Xilinx, Inc
