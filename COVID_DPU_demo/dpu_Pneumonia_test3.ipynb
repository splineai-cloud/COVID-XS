# %% [markdown]
# # DPU example: Pneumonia/COVID Detection Model - Pnem3
#
# This notebooks shows an example of DPU applications. The application,
# as well as the DPU IP, is pulled from the official
# [Vitis AI Github Repository](https://github.com/Xilinx/Vitis-AI).
# For more information, please refer to the
# [Xilinx Vitis AI page](https://www.xilinx.com/products/design-tools/vitis/vitis-ai.html).
#
# In this notebook, we will show how to use **Python API** to run DPU tasks.
#
# ## 1. Prepare the overlay
# We will download the overlay onto the board.

# %%
from pynq_dpu import DpuOverlay
overlay = DpuOverlay("../dpu.bit")

# %% [markdown]
# The VAI package has been installed onto your board. There are multiple
# binaries installed; for example, you can check the current DPU status using
# `dexplorer`. You should be able to see reasonable values from the output.

# %% [markdown]
# !dexplorer -w

# %%
#!dexplorer -h

# %% [markdown]
# The compiled quantized model may have different kernel names depending on the DPU architectures.
# This piece of information can usually be found when compiling the `*.elf` model file.
#
# The `*.elf` model will be compiled into a shared object file; that file has to be copied to your
# library path for inference in DPU.
#
# By default, the naming convention for model files is:
#
# * Model `*.elf` file: `dpu_<kernel_name>[_0].elf`
# * Shared object `*.so` file: `libdpumodel<kernel_name>.elf`
#
# All of these steps are handled by `load_model()` method.

# %%
overlay.load_model("./models/dpu_Pnem3_0.elf")

# %% [markdown]
# ## 2. Run Python program
#
# We will use Vitis-AI's Python API to run DPU tasks.
# In this example, we will set the number of iterations to 500, meaning
# that a single picture will be taken and classified 500 times.
# Users can adjust this value if they want.

# %%
from ctypes import *
import cv2
import numpy as np
from dnndk import n2cube
import os
import threading
import time
from pynq_dpu import dputils  

lock = threading.Lock()

# %%
#*** Pneumonia and COVID detection Model with 150x150 X-Ray image input

KERNEL_CONV = "Pnem3_0"  
KERNEL_CONV_INPUT = "conv2d_1_convolution"
KERNEL_FC_OUTPUT = "dense_out_MatMul" 

img_dims=150

# %% [markdown]
# The ./data/ folder contains two subfolders with set of X-Ray images 1) sample - with 30 images and 2) images - with 1100 images

# %%
from IPython.display import display
from PIL import Image
 
image_folder = "./data/samples/"    
listimage = [i for i in os.listdir(image_folder)]
print("Sample Image Count={}".format(len(listimage)))  
imfile = listimage[0]
with open("./labels.txt", "r") as f:
    lines = f.readlines()
# Out:
# Sample Image Count=53

# %% [markdown]
# We will also open and initialize the DPU device. We will create a DPU kernel and reuse it.
# Throughout the entire notebook, we don't have to redo this step.
#
# **Note**: if you open and close DPU multiple times, the Jupyter kernel might die;
# this is because the current Vitis-AI implementation requires bitstream to be downloaded by XRT,
# which is not supported by `pynq` package. Hence we encourage users to stay with
# one single DPU session, both for program robustness and higher performance.

# %%
n2cube.dpuOpen()
# Out:
# 0

# %%
kernel = n2cube.dpuLoadKernel(KERNEL_CONV)

# %% [markdown]
# ### Single execution
# We define a function that will use the DPU to make a prediction on an input
# image and provide a softmax output.

# %%
def predict_label(imfile):
    task = n2cube.dpuCreateTask(kernel, 0)

    path = os.path.join(image_folder, imfile)
    img = cv2.imread(path) 
    img = cv2.resize(img, (img_dims, img_dims))
    img = img.astype(np.float32)
    img = (img/255.0) 
        
    """Get input Tensor"""
    tensor = n2cube.dpuGetInputTensor(task, KERNEL_CONV_INPUT)
    input_len = n2cube.dpuGetInputTensorSize(task, KERNEL_CONV_INPUT)   
    #print(input_len)
        
    """Set input Tensor"""
    n2cube.dpuSetInputTensorInHWCFP32(task, KERNEL_CONV_INPUT, img, input_len)

    """Model run on DPU"""
    n2cube.dpuRunTask(task)
        
    """Get the output Tensor size from FC output"""
    size = n2cube.dpuGetOutputTensorSize(task, KERNEL_FC_OUTPUT)

    """Get the output Tensor channel from FC output"""
    channel = n2cube.dpuGetOutputTensorChannel(task, KERNEL_FC_OUTPUT)

    softmax = np.zeros(size,dtype=np.float32)

    """Get FC result"""
    conf = n2cube.dpuGetOutputTensorAddress(task, KERNEL_FC_OUTPUT)

    """Get output scale of FC"""
    outputScale = n2cube.dpuGetOutputTensorScale(task, KERNEL_FC_OUTPUT)

    """Run softmax"""
    softmax = n2cube.dpuRunSoftmax(conf, channel, size // channel, outputScale)
     
    #print("size=", size)
    #print("channel=", channel)
    #print("outputScale=", outputScale)
    print("softmax =", softmax)

    n2cube.dpuDestroyTask(task)
    
    return lines[np.argmax(softmax)]

# %%
print("INFO: test with sample X-Ray images")
i = 0
for img in listimage:
    print("{}  {}".format(i, img))
    i = i + 1 
    label = predict_label(img)
    print('Class label: {}'.format(label))
# Out:
# INFO: test with sample X-Ray images
# 0  COVID_1-s2.0-S1684118220300608-main.pdf-002.jpg
# softmax = [ 0.01752752  0.02550239  0.9569701 ]
# Class label: COVID
#
# 1  COVID_covid-19-pneumonia-53.jpg
# softmax = [  9.73872304e-01   2.59528179e-02   1.74868706e-04]
# Class label: NORMAL
#
# 2  PNEUMONIA_fe1289af-87c8-49c6-800c-1e87b2296df8.jpg
# softmax = [  2.29861223e-04   9.96969879e-01   2.80028302e-03]
# Class label: PNEUMONIA
#
# 3  NORMAL_8d3d0ba6-799d-4874-a804-75a4c0cf4ae6.jpg
# softmax = [ 0.07070307  0.40686801  0.52242893]
# Class label: COVID
#
# 4  COVID_covid-19-pneumonia-8.jpg
# softmax = [  5.81280037e-05   2.80076405e-03   9.97141123e-01]
# Class label: COVID
#
# 5  PNEUMONIA_849217ad-5cb2-4a87-9796-420b69722b14.jpg
# softmax = [ 0.01766842  0.96466309  0.01766842]
# Class label: PNEUMONIA
#
# 6  COVID_COVID-00027.jpg
# softmax = [  2.60980363e-04   8.03876086e-04   9.98935163e-01]
# Class label: COVID
#
# 7  NORMAL_8cfcc69b-d659-4888-8551-790891d8568e.jpg
# softmax = [  9.73872304e-01   2.59528179e-02   1.74868706e-04]
# Class label: NORMAL
#
# 8  COVID_COVID-00038.jpg
# softmax = [ 0.0069369   0.90855438  0.08450872]
# Class label: PNEUMONIA
#
# 9  COVID_COVID-00006.jpg
# softmax = [  2.03121657e-04   1.50087732e-03   9.98295963e-01]
# Class label: COVID
#
# 10  PNEUMONIA_852156be-0aab-4dc7-95d6-eda950096d0f.jpg
# softmax = [ 0.37551838  0.61912519  0.00535648]
# Class label: PNEUMONIA
#
# 11  PNEUMONIA_84032d11-9143-45a2-b3e9-955f9dc4b497.jpg
# softmax = [ 0.00605856  0.89916968  0.09477179]
# Class label: PNEUMONIA
#
# 12  NORMAL_fc4cd37e-7bae-425d-9465-bfdd0ecf0b63.jpg
# softmax = [  9.73872304e-01   2.59528179e-02   1.74868706e-04]
# Class label: NORMAL
#
# 13  PNEUMONIA_fef7b294-017c-4491-9e57-119086855785.jpg
# softmax = [  3.11797703e-05   9.99259174e-01   7.09648302e-04]
# Class label: PNEUMONIA
#
# 14  PNEUMONIA_85727853-cb45-478d-a517-a0f0c85d0eb5.jpg
# softmax = [ 0.00265174  0.94408655  0.05326172]
# Class label: PNEUMONIA
#
# 15  NORMAL_8c62b364-84be-4c83-9c3a-43df335a1978.jpg
# softmax = [  1.64457291e-01   8.35182965e-01   3.59748869e-04]
# Class label: PNEUMONIA
#
# 16  COVID_extubation-4.jpg
# softmax = [ 0.00107009  0.08500798  0.91392189]
# Class label: COVID
#
# 17  NORMAL_fc6599d7-fa85-4361-b26e-e51f2375ecf2.jpg
# softmax = [  9.73872304e-01   2.59528179e-02   1.74868706e-04]
# Class label: NORMAL
#
# 18  NORMAL_8d091d33-6dfc-431e-b459-995016771709.jpg
# softmax = [  9.73872304e-01   2.59528179e-02   1.74868706e-04]
# Class label: NORMAL
#
# 19  COVID_gr1_lrg-b.jpg
# softmax = [  5.82628309e-05   4.87828715e-04   9.99453962e-01]
# Class label: COVID
#
# 20  COVID_covid-19-pneumonia-19.jpg
# softmax = [ 0.02721451  0.17746089  0.79532462]
# Class label: COVID
#
# 21  PNEUMONIA_fdfce1ff-203e-4b23-a360-3803558a7f7a.jpg
# softmax = [  4.25206788e-04   9.87148404e-01   1.24263633e-02]
# Class label: PNEUMONIA
#
# 22  COVID_16654_2_1.jpg
# softmax = [ 0.00555787  0.93468946  0.0597527 ]
# Class label: PNEUMONIA
#
# 23  NORMAL_fe8460ea-9f61-4f29-b315-ffb5c01f4eef.jpg
# softmax = [  9.73872304e-01   2.59528179e-02   1.74868706e-04]
# Class label: NORMAL
#
# 24  PNEUMONIA_fe2e6108-895f-4469-8712-7965544dd47c.jpg
# softmax = [ 0.09451126  0.89669782  0.00879092]
# Class label: PNEUMONIA
#
# 25  COVID_AR-1.jpg
# softmax = [  4.87027777e-04   1.69989397e-03   9.97813046e-01]
# Class label: COVID
#
# 26  NORMAL_8c82ad94-205c-435a-a510-e4be16cf5657.jpg
# softmax = [  8.66668999e-01   1.32907987e-01   4.23017016e-04]
# Class label: NORMAL
#
# 27  PNEUMONIA_863a923a-3906-42d3-92db-76c900091fce.jpg
# softmax = [ 0.00964412  0.98372751  0.0066283 ]
# Class label: PNEUMONIA
#
# 28  PNEUMONIA_844ac956-e1e2-4f27-b58c-390d6405c3a0.jpg
# softmax = [ 0.00589974  0.77271396  0.22138625]
# Class label: PNEUMONIA
#
# 29  NORMAL_fca8b18a-9851-4115-af53-6d7540820888.jpg
# softmax = [ 0.9240064   0.05906975  0.01692377]
# Class label: NORMAL
#
# 30  NORMAL_8c4421ee-115a-472c-b3cd-48c6c3b8e42b.jpg
# softmax = [ 0.40708411  0.59230387  0.00061203]
# Class label: PNEUMONIA
#
# 31  NORMAL_fe02ac25-6a2a-4c6b-909e-c8a9c7c67f53.jpg
# softmax = [  9.73872304e-01   2.59528179e-02   1.74868706e-04]
# Class label: NORMAL
#
# 32  PNEUMONIA_86e9848d-dd57-48b4-b016-5b1447fdbd58.jpg
# softmax = [  1.86898815e-05   9.87549961e-01   1.24314185e-02]
# Class label: PNEUMONIA
#
# 33  COVID_88de9d8c39e946abd495b37cd07d89e5-2ee6-0.jpg
# softmax = [ 0.02271238  0.31353471  0.66375297]
# Class label: COVID
#
# 34  COVID_covid-19-pneumonia-58-day-3.jpg
# softmax = [  9.09845112e-04   1.32381683e-03   9.97766376e-01]
# Class label: COVID
#
# 35  COVID_COVID-00001.jpg
# softmax = [  2.95512960e-04   1.50073867e-03   9.98203754e-01]
# Class label: COVID
#
# 36  NORMAL_fc35980f-918e-4f10-b3e4-d4202394e7da.jpg
# softmax = [  9.73872304e-01   2.59528179e-02   1.74868706e-04]
# Class label: NORMAL
#
# 37  COVID_COVID-00016.jpg
# softmax = [  2.60798348e-04   1.50079082e-03   9.98238444e-01]
# Class label: COVID
#
# 38  NORMAL_8d768b9e-92cb-4343-9a2a-20ce3d137695.jpg
# softmax = [  9.73761857e-01   2.59498730e-02   2.88277050e-04]
# Class label: NORMAL
#
# 39  COVID_COVID-00033.jpg
# softmax = [ 0.00217852  0.22221498  0.77560645]
# Class label: COVID
#
# 40  NORMAL_fcbe3898-4d24-402a-a64a-f11c95d23235.jpg
# softmax = [  9.32029068e-01   6.75159618e-02   4.54918947e-04]
# Class label: NORMAL
#
# 41  COVID_COVID-00037.jpg
# softmax = [ 0.00159663  0.26851201  0.72989136]
# Class label: COVID
#
# 42  PNEUMONIA_02c34d5b-16e9-412e-a385-ccd8cbceae16.jpg
# softmax = [  4.87856974e-04   9.99511838e-01   2.38120677e-07]
# Class label: PNEUMONIA
#
# 43  COVID_extubation-13.jpg
# softmax = [ 0.00186311  0.03302434  0.96511257]
# Class label: COVID
#
# 44  PNEUMONIA_8489c930-19a8-4895-9211-4efd3d38ae58.jpg
# softmax = [  9.14582849e-01   8.50694552e-02   3.47659428e-04]
# Class label: NORMAL
#
# 45  COVID_covid-19-pneumonia-20-pa-on-admission.jpg
# softmax = [ 0.0031282   0.01401963  0.9828521 ]
# Class label: COVID
#
# 46  PNEUMONIA_fcf5cd90-1a5d-4e45-925e-ff82dcbdc0ad.jpg
# softmax = [  4.87856596e-04   9.99511123e-01   1.06718198e-06]
# Class label: PNEUMONIA
#
# 47  PNEUMONIA_fcd6452c-680d-40a6-9fc6-1793eb3ca0a8.jpg
# softmax = [  6.26332127e-04   9.99370396e-01   3.28668921e-06]
# Class label: PNEUMONIA
#
# 48  COVID_16708_5_1.jpg
# softmax = [ 0.19313848  0.132742    0.67411947]
# Class label: COVID
#
# 49  COVID_COVID-00036.jpg
# softmax = [ 0.0010979   0.73025596  0.26864615]
# Class label: PNEUMONIA
#
# 50  NORMAL_8c2b6caa-41cd-45c0-95f0-de71c3e9186b.jpg
# softmax = [ 0.9122445   0.08485196  0.00290347]
# Class label: NORMAL
#
# 51  COVID_16660_2_1.jpg
# softmax = [ 0.0073169   0.8457191   0.14696395]
# Class label: PNEUMONIA
#
# 52  COVID_kjr-21-e24-g002-l-a.jpg
# softmax = [ 0.06644192  0.12412983  0.80942822]
# Class label: COVID

# %% [markdown]
# ### Multiple executions
# After we have verified the correctness of a single execution, we can
# try multiple executions and measure the throughput in Frames Per Second (FPS).
#
# Let's define a function that processes a single image in multiple iterations.
# The parameters are:
# * `kernel`: DPU kernel.
# * `img`: image to be classified.
# * `count` : test rounds count.
#
# The number of iterations is defined as `num_iterations` in previous cells.

# %%
path = os.path.join(image_folder, imfile)
img = cv2.imread(path) 
img = cv2.resize(img, (img_dims, img_dims))
img = img.astype(np.float32)
img = (img/255.0) 

def run_dpu_task(kernel, img, count):
    task = n2cube.dpuCreateTask(kernel, 0)
    
    count = 0
    while count < num_iterations:
           
        """Get input Tensor"""
        tensor = n2cube.dpuGetInputTensor(task, KERNEL_CONV_INPUT)
        input_len = n2cube.dpuGetInputTensorSize(task, KERNEL_CONV_INPUT)   
        
        """Set input Tensor"""
        n2cube.dpuSetInputTensorInHWCFP32(task, KERNEL_CONV_INPUT, img, input_len)

        """Model run on DPU"""
        n2cube.dpuRunTask(task)
        
        """Get the output Tensor size from FC output"""
        size = n2cube.dpuGetOutputTensorSize(task, KERNEL_FC_OUTPUT)

        """Get the output Tensor channel from FC output"""
        channel = n2cube.dpuGetOutputTensorChannel(task, KERNEL_FC_OUTPUT)

        softmax = np.zeros(size,dtype=np.float32)

        """Get FC result"""
        conf = n2cube.dpuGetOutputTensorAddress(task, KERNEL_FC_OUTPUT)

        """Get output scale of FC"""
        outputScale = n2cube.dpuGetOutputTensorScale(task, KERNEL_FC_OUTPUT)

        """Run softmax"""
        softmax = n2cube.dpuRunSoftmax(conf, channel, size // channel, outputScale)

        lock.acquire()
        count = count + threadnum
        lock.release()

    n2cube.dpuDestroyTask(task)

# %% [markdown]
# Now we are able to run the batch processing and print out DPU throughput.
# Users can change the image to point to other picture locations.
# We will use the previously defined and classified image `img` and process it for
# `num_interations` times.
#
# In this example, we will just use a single thread.
#
# The following cell may take a while to run. Please be patient.

# %%
threadAll = []
threadnum = 1
num_iterations = 500
start = time.time()

for i in range(threadnum):
    t1 = threading.Thread(target=run_dpu_task, args=(kernel, img, i))
    threadAll.append(t1)
for x in threadAll:
    x.start()
for x in threadAll:
    x.join()

end = time.time()

fps = float(num_iterations/(end-start))
print("%.2f FPS" % fps)
# Out:
# 111.48 FPS

# %%
threadAll = []
threadnum = 4
num_iterations = 500
start = time.time()

for i in range(threadnum):
    t1 = threading.Thread(target=run_dpu_task, args=(kernel, img, i))
    threadAll.append(t1)
for x in threadAll:
    x.start()
for x in threadAll:
    x.join()

end = time.time()

fps = float(num_iterations/(end-start))
print("%.2f FPS" % fps)
# Out:
# 190.37 FPS

# %%
threadAll = []
threadnum = 8
num_iterations = 500
start = time.time()

for i in range(threadnum):
    t1 = threading.Thread(target=run_dpu_task, args=(kernel, img, i))
    threadAll.append(t1)
for x in threadAll:
    x.start()
for x in threadAll:
    x.join()

end = time.time()

fps = float(num_iterations/(end-start))
print("%.2f FPS" % fps)
# Out:
# 186.88 FPS

# %%
def run_tasks(kernel):
    task = n2cube.dpuCreateTask(kernel, 0)
    
    o_count = [0, 0, 0]
    p_count = [0, 0, 0]
     
    image_folder = "./data/images/"  
    listimage = [i for i in os.listdir(image_folder)] 
    num_iterations=len(listimage)
    print("Total Test Image Count={}".format(num_iterations)) 
    count = 0

    with open("./labels.txt", "r") as f:
        lines = f.readlines()
        
    print("====================== Start: Test results with 100 COVID mark X-Rays ==================")
    while count < num_iterations:
        imfile = listimage[count]
        path = os.path.join(image_folder, imfile)
        img = cv2.imread(path) 
        img = cv2.resize(img, (img_dims, img_dims))
        img = img.astype(np.float32)
        img = (img/255.0) 
        
        """Get input Tensor"""
        tensor = n2cube.dpuGetInputTensor(task, KERNEL_CONV_INPUT)
        input_len = n2cube.dpuGetInputTensorSize(task, KERNEL_CONV_INPUT)   
        #print(input_len)
        
        """Set input Tensor"""
        n2cube.dpuSetInputTensorInHWCFP32(task, KERNEL_CONV_INPUT, img, input_len)

        """Model run on DPU"""
        n2cube.dpuRunTask(task)
        
        """Get the output Tensor size from FC output"""
        size = n2cube.dpuGetOutputTensorSize(task, KERNEL_FC_OUTPUT)

        """Get the output Tensor channel from FC output"""
        channel = n2cube.dpuGetOutputTensorChannel(task, KERNEL_FC_OUTPUT)

        softmax = np.zeros(size,dtype=np.float32)

        """Get FC result"""
        conf = n2cube.dpuGetOutputTensorAddress(task, KERNEL_FC_OUTPUT)

        """Get output scale of FC"""
        outputScale = n2cube.dpuGetOutputTensorScale(task, KERNEL_FC_OUTPUT)

        """Run softmax"""
        softmax = n2cube.dpuRunSoftmax(conf, channel, size // channel, outputScale)

        expected = False
        if imfile[0] == 'N':  
            o_count[0] = o_count[0] + 1 
        elif imfile[0] == 'P':
            o_count[1] = o_count[1] + 1 
        elif imfile[0] == 'C':
            o_count[2] = o_count[2] + 1 
        else:
            print("ERROR: Invalid file tag in {}".format(imfile))
        
        label = np.argmax(softmax)
        p_count[label] = p_count[label] + 1 
        slabel = lines[label] 
        if imfile[0] == 'C':
            print("Name= {}  Softmax={}  Prediction= {}".format(imfile, softmax, slabel))
        count = count + 1
    print("====================== Done: Test results with COVID mark X-Rays ==================")
    print("\n")
    print("====================== Start: Test results with All X-Rays ==================")
    print("Actual #(NORMAL, PNEUMONIA, COVID)= ({}, {}, {})". format(o_count[0], o_count[1], o_count[2]))
    print("Predic #(NORMAL, PNEUMONIA, COVID)= ({}, {}, {})". format(p_count[0], p_count[1], p_count[2]))
    print("Percentage Prediction (NORMAL, PNEUMONIA, COVID)=({}, {}, {})".format((p_count[0]*100)/o_count[0], (p_count[1]*100)/o_count[1],
                                                                                 (p_count[2]*100)/o_count[2])) 
    n2cube.dpuDestroyTask(task)

# %%
run_tasks(kernel)
# Out:
# Total Test Image Count=1100
# ====================== Start: Test results with 100 COVID mark X-Rays ==================
# Name= COVID_COVID-19(153).png  Softmax=[ 0.0228271   0.00654007  0.97063279]  Prediction= COVID
#
# Name= COVID_1-s2.0-S1684118220300608-main.pdf-002.jpg  Softmax=[ 0.01752752  0.02550239  0.9569701 ]  Prediction= COVID
#
# Name= COVID_covid-19-pneumonia-53.jpg  Softmax=[  9.73872304e-01   2.59528179e-02   1.74868706e-04]  Prediction= NORMAL
#
# Name= COVID_COVID-19 (128).png  Softmax=[  9.09297436e-04   1.92498276e-03   9.97165740e-01]  Prediction= COVID
#
# Name= COVID_COVID-19 (55).png  Softmax=[ 0.00102748  0.00460484  0.99436772]  Prediction= COVID
#
# Name= COVID_covid-19-pneumonia-8.jpg  Softmax=[  5.81280037e-05   2.80076405e-03   9.97141123e-01]  Prediction= COVID
#
# Name= COVID_covid-19-pneumonia-14-PA.png  Softmax=[  1.23295365e-04   8.03986797e-04   9.99072731e-01]  Prediction= COVID
#
# Name= COVID_F63AB6CE-1968-4154-A70F-913AF154F53D.jpeg  Softmax=[ 0.00747147  0.01395855  0.97856992]  Prediction= COVID
#
# Name= COVID_COVID-19 (131).png  Softmax=[ 0.00333011  0.18181801  0.81485182]  Prediction= COVID
#
# Name= COVID_COVID-19 (14).png  Softmax=[ 0.00261223  0.06737025  0.93001753]  Prediction= COVID
#
# Name= COVID_1-s2.0-S1684118220300682-main.pdf-003-b1.png  Softmax=[ 0.02013893  0.00951296  0.97034812]  Prediction= COVID
#
# Name= COVID_COVID-19(193).png  Softmax=[ 0.16210139  0.11141054  0.72648805]  Prediction= COVID
#
# Name= COVID_COVID-19 (2).png  Softmax=[  4.87125129e-04   1.50045089e-03   9.98012424e-01]  Prediction= COVID
#
# Name= COVID_COVID-00027.jpg  Softmax=[  2.60980363e-04   8.03876086e-04   9.98935163e-01]  Prediction= COVID
#
# Name= COVID_COVID-19 (57).png  Softmax=[ 0.00131367  0.00856622  0.99012017]  Prediction= COVID
#
# Name= COVID_CR.1.2.840.113564.1722810170.20200320183426328780.1003000225002.png  Softmax=[  3.73162553e-02   9.62398887e-01   2.84913112e-04]  Prediction= PNEUMONIA
#
# Name= COVID_COVID-19(195).png  Softmax=[ 0.0225839   0.12996139  0.84745467]  Prediction= COVID
#
# Name= COVID_COVID-19(164).png  Softmax=[ 0.00945885  0.02571183  0.96482927]  Prediction= COVID
#
# Name= COVID_1.CXRCTThoraximagesofCOVID-19fromSingapore.pdf-002-fig3b.png  Softmax=[  3.34145443e-04   3.59240174e-03   9.96073484e-01]  Prediction= COVID
#
# Name= COVID_COVID-19 (4).png  Softmax=[  7.36557849e-05   1.59052201e-02   9.84021127e-01]  Prediction= COVID
#
# Name= COVID_COVID-19 (81).png  Softmax=[  3.09342831e-05   8.57722014e-03   9.91391838e-01]  Prediction= COVID
#
# Name= COVID_COVID-19(208).png  Softmax=[  1.77988346e-04   8.57595820e-03   9.91246045e-01]  Prediction= COVID
#
# Name= COVID_COVID-19(188).png  Softmax=[ 0.00436448  0.05317025  0.94246525]  Prediction= COVID
#
# Name= COVID_6b44464d-73a7-4cf3-bbb6-ffe7168300e3.annot.original.jpeg  Softmax=[ 0.93798476  0.05996337  0.00205183]  Prediction= NORMAL
#
# Name= COVID_ciaa199.pdf-001-c.png  Softmax=[ 0.00316132  0.00358224  0.99325645]  Prediction= COVID
#
# Name= COVID_CR.1.2.840.113564.1722810170.20200321002029359840.1003000225002.png  Softmax=[ 0.21336758  0.12941398  0.6572184 ]  Prediction= COVID
#
# Name= COVID_85E52EB3-56E9-4D67-82DA-DEA247C82886.jpeg  Softmax=[ 0.00245395  0.46764022  0.52990586]  Prediction= COVID
#
# Name= COVID_COVID-19 (94).png  Softmax=[ 0.00325207  0.09503938  0.90170854]  Prediction= COVID
#
# Name= COVID_COVID-00038.jpg  Softmax=[ 0.0069369   0.90855438  0.08450872]  Prediction= PNEUMONIA
#
# Name= COVID_COVID-00006.jpg  Softmax=[  2.03121657e-04   1.50087732e-03   9.98295963e-01]  Prediction= COVID
#
# Name= COVID_COVID-19 (24).png  Softmax=[  6.25602144e-04   1.16877863e-03   9.98205602e-01]  Prediction= COVID
#
# Name= COVID_COVID-19 (6).png  Softmax=[  8.01835558e-04   2.79868091e-03   9.96399522e-01]  Prediction= COVID
#
# Name= COVID_COVID-19 (65).png  Softmax=[ 0.92250484  0.04592881  0.03156638]  Prediction= NORMAL
#
# Name= COVID_CR.1.2.840.113564.1722810170.20200402113955515630.1003000225002.png  Softmax=[ 0.00103024  0.11908012  0.87988967]  Prediction= COVID
#
# Name= COVID_COVID-19 (71).png  Softmax=[  3.79638455e-04   9.10705305e-04   9.98709679e-01]  Prediction= COVID
#
# Name= COVID_covid-19-pneumonia-67.jpeg  Softmax=[ 0.00259541  0.18195204  0.81545252]  Prediction= COVID
#
# Name= COVID_COVID-19(174).png  Softmax=[ 0.0107372   0.02273066  0.96653211]  Prediction= COVID
#
# Name= COVID_COVID-19 (44).png  Softmax=[  2.30362377e-04   6.26189867e-04   9.99143422e-01]  Prediction= COVID
#
# Name= COVID_extubation-4.jpg  Softmax=[ 0.00107009  0.08500798  0.91392189]  Prediction= COVID
#
# Name= COVID_COVID-19 (108).png  Softmax=[ 0.01389122  0.01225896  0.97384977]  Prediction= COVID
#
# Name= COVID_COVID-19 (1).png  Softmax=[  2.95719190e-04   8.03848088e-04   9.98900414e-01]  Prediction= COVID
#
# Name= COVID_COVID-19(187).png  Softmax=[  5.51714154e-04   9.97522652e-01   1.92567159e-03]  Prediction= PNEUMONIA
#
# Name= COVID_gr1_lrg-b.jpg  Softmax=[  5.82628309e-05   4.87828715e-04   9.99453962e-01]  Prediction= COVID
#
# Name= COVID_COVID-19 (117).png  Softmax=[ 0.00131964  0.00406477  0.99461555]  Prediction= COVID
#
# Name= COVID_CD50BA96-6982-4C80-AE7B-5F67ACDBFA56.jpeg  Softmax=[ 0.01881901  0.07443061  0.90675044]  Prediction= COVID
#
# Name= COVID_covid-19-pneumonia-19.jpg  Softmax=[ 0.02721451  0.17746089  0.79532462]  Prediction= COVID
#
# Name= COVID_16654_2_1.jpg  Softmax=[ 0.00555787  0.93468946  0.0597527 ]  Prediction= PNEUMONIA
#
# Name= COVID_03BF7561-A9BA-4C3C-B8A0-D3E585F73F3C.jpeg  Softmax=[ 0.00897862  0.07517708  0.91584432]  Prediction= COVID
#
# Name= COVID_AR-1.jpg  Softmax=[  4.87027777e-04   1.69989397e-03   9.97813046e-01]  Prediction= COVID
#
# Name= COVID_1B734A89-A1BF-49A8-A1D3-66FAFA4FAC5D.jpeg  Softmax=[ 0.46439162  0.07121676  0.46439162]  Prediction= NORMAL
#
# Name= COVID_COVID-19(216).png  Softmax=[ 0.01795219  0.11706296  0.86498487]  Prediction= COVID
#
# Name= COVID_COVID-19 (10).png  Softmax=[ 0.01235908  0.00583801  0.98180294]  Prediction= COVID
#
# Name= COVID_COVID-19 (72).png  Softmax=[ 0.04997639  0.06417095  0.88585263]  Prediction= COVID
#
# Name= COVID_CR.1.2.840.113564.1722810170.20200320103403375580.1003000225002.png  Softmax=[ 0.00473303  0.29282242  0.70244449]  Prediction= COVID
#
# Name= COVID_16669_3_1.jpeg  Softmax=[ 0.00996714  0.29128247  0.69875038]  Prediction= COVID
#
# Name= COVID_2966893D-5DDF-4B68-9E2B-4979D5956C8E.jpeg  Softmax=[  2.27265686e-04   1.40604293e-02   9.85712290e-01]  Prediction= COVID
#
# Name= COVID_88de9d8c39e946abd495b37cd07d89e5-2ee6-0.jpg  Softmax=[ 0.02271238  0.31353471  0.66375297]  Prediction= COVID
#
# Name= COVID_COVID-19 (109).png  Softmax=[  3.53390060e-05   4.87839890e-04   9.99476850e-01]  Prediction= COVID
#
# Name= COVID_covid-19-pneumonia-58-day-3.jpg  Softmax=[  9.09845112e-04   1.32381683e-03   9.97766376e-01]  Prediction= COVID
#
# Name= COVID_COVID-00001.jpg  Softmax=[  2.95512960e-04   1.50073867e-03   9.98203754e-01]  Prediction= COVID
#
# Name= COVID_fff49165-b22d-4bb4-b9d1-d5d62c52436c.annot.original.png  Softmax=[ 0.094696    0.48090595  0.42439803]  Prediction= PNEUMONIA
#
# Name= COVID_COVID-19 (29).png  Softmax=[  2.42401566e-05   2.47256318e-03   9.97503221e-01]  Prediction= COVID
#
# Name= COVID_COVID-19 (76).png  Softmax=[  1.79459748e-04   3.79916310e-04   9.99440610e-01]  Prediction= COVID
#
# Name= COVID_COVID-00016.jpg  Softmax=[  2.60798348e-04   1.50079082e-03   9.98238444e-01]  Prediction= COVID
#
# Name= COVID_COVID-00033.jpg  Softmax=[ 0.00217852  0.22221498  0.77560645]  Prediction= COVID
#
# Name= COVID_COVID-19(148).png  Softmax=[ 0.0014707   0.02030245  0.9782269 ]  Prediction= COVID
#
# Name= COVID_COVID-19(210).png  Softmax=[ 0.00490801  0.05979175  0.93530023]  Prediction= COVID
#
# Name= COVID_COVID-19 (22).png  Softmax=[  3.33804812e-04   4.60803369e-03   9.95058179e-01]  Prediction= COVID
#
# Name= COVID_COVID-19 (133).png  Softmax=[  1.39430485e-04   2.80053634e-03   9.97060061e-01]  Prediction= COVID
#
# Name= COVID_8FDE8DBA-CFBD-4B4C-B1A4-6F36A93B7E87.jpeg  Softmax=[ 0.87748748  0.0924865   0.03002597]  Prediction= NORMAL
#
# Name= COVID_CR.1.2.840.113564.1722810170.20200320071047906500.1003000225002.png  Softmax=[  1.78958493e-04   3.17211519e-03   9.96648967e-01]  Prediction= COVID
#
# Name= COVID_COVID-00037.jpg  Softmax=[ 0.00159663  0.26851201  0.72989136]  Prediction= COVID
#
# Name= COVID_nejmoa2001191_f3-PA.jpeg  Softmax=[ 0.0066198   0.01091421  0.98246598]  Prediction= COVID
#
# Name= COVID_extubation-13.jpg  Softmax=[ 0.00186311  0.03302434  0.96511257]  Prediction= COVID
#
# Name= COVID_covid-19-pneumonia-20-pa-on-admission.jpg  Softmax=[ 0.0031282   0.01401963  0.9828521 ]  Prediction= COVID
#
# Name= COVID_COVID-19 (15).png  Softmax=[ 0.01609814  0.10497307  0.87892878]  Prediction= COVID
#
# Name= COVID_COVID-19(165).png  Softmax=[ 0.00945885  0.02571183  0.96482927]  Prediction= COVID
#
# Name= COVID_COVID-19(170).png  Softmax=[ 0.72648799  0.16210139  0.11141054]  Prediction= NORMAL
#
# Name= COVID_COVID-19 (66).png  Softmax=[ 0.09489896  0.90037632  0.00472474]  Prediction= PNEUMONIA
#
# Name= COVID_31BA3780-2323-493F-8AED-62081B9C383B.jpeg  Softmax=[  1.36193165e-04   2.59538218e-02   9.73909974e-01]  Prediction= COVID
#
# Name= COVID_COVID-19(209).png  Softmax=[ 0.00490801  0.05979175  0.93530023]  Prediction= COVID
#
# Name= COVID_6CB4EFC6-68FA-4CD5-940C-BEFA8DAFE9A7.jpeg  Softmax=[ 0.00199734  0.08492907  0.9130736 ]  Prediction= COVID
#
# Name= COVID_COVID-19 (52).png  Softmax=[ 0.00132175  0.00246936  0.99620891]  Prediction= COVID
#
# Name= COVID_16708_5_1.jpg  Softmax=[ 0.19313848  0.132742    0.67411947]  Prediction= COVID
#
# Name= COVID_COVID-00036.jpg  Softmax=[ 0.0010979   0.73025596  0.26864615]  Prediction= PNEUMONIA
#
# Name= COVID_COVID-19 (73).png  Softmax=[ 0.00246125  0.00459823  0.99294049]  Prediction= COVID
#
# Name= COVID_covid-19-pneumonia-28.png  Softmax=[ 0.0184613   0.2887834   0.69275534]  Prediction= COVID
#
# Name= COVID_ciaa199.pdf-001-b.png  Softmax=[  8.03146337e-04   1.16857095e-03   9.98028278e-01]  Prediction= COVID
#
# Name= COVID_COVID-19 (31).png  Softmax=[  3.79252655e-04   1.92600384e-03   9.97694731e-01]  Prediction= COVID
#
# Name= COVID_16660_2_1.jpg  Softmax=[ 0.0073169   0.8457191   0.14696395]  Prediction= PNEUMONIA
#
# Name= COVID_kjr-21-e24-g002-l-a.jpg  Softmax=[ 0.06644192  0.12412983  0.80942822]  Prediction= COVID
#
# Name= COVID_COVID-19 (59).png  Softmax=[  8.03021365e-04   1.32395839e-03   9.97873068e-01]  Prediction= COVID
#
# Name= COVID_COVID-19(203).png  Softmax=[ 0.01065356  0.74687248  0.24247397]  Prediction= PNEUMONIA
#
# Name= COVID_COVID-19 (45).png  Softmax=[  8.90136347e-04   2.29569189e-02   9.76152956e-01]  Prediction= COVID
#
# Name= COVID_COVID-19 (51).png  Softmax=[ 0.07424457  0.02127143  0.90448403]  Prediction= COVID
#
# Name= COVID_COVID-19 (12).png  Softmax=[  9.46210861e-01   5.33815622e-02   4.07573272e-04]  Prediction= NORMAL
#
# Name= COVID_COVID-19 (91).png  Softmax=[ 0.05821436  0.0311599   0.91062576]  Prediction= COVID
#
# Name= COVID_ryct.2020200034.fig5-day0.jpeg  Softmax=[ 0.05985672  0.93631679  0.00382651]  Prediction= PNEUMONIA
#
# Name= COVID_CR.1.2.840.113564.1722810170.20200329171322703880.1003000225002.png  Softmax=[ 0.00668004  0.22121251  0.77210748]  Prediction= COVID
#
# Name= COVID_COVID-19(218).png  Softmax=[ 0.0064627   0.14709042  0.84644687]  Prediction= COVID
#
# ====================== Done: Test results with COVID mark X-Rays ==================
#
#
# ====================== Start: Test results with All X-Rays ==================
# Actual #(NORMAL, PNEUMONIA, COVID)= (500, 500, 100)
# Predic #(NORMAL, PNEUMONIA, COVID)= (519, 488, 93)
# Percentage Prediction (NORMAL, PNEUMONIA, COVID)=(103.8, 97.6, 93.0)

# %% [markdown]
# ### Clean up
#
# Finally, when you are done with the DPU experiments, remember to destroy the kernel and close the DPU.

# %%
n2cube.dpuDestroyKernel(kernel)
n2cube.dpuClose()
# Out:
# 0
